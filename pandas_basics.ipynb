# %%
import pandas as pd

# %%
a=pd.Series([10,20,30,40])
print(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
print(a[2])
# Out:
# 30

# %%
print(a.values)
# Out:
# [10 20 30 40]

# %%
print(a.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df=pd.read_csv("Data set.csv")

# %%
df
# Out:
#     Token No           Name  Age  Gender  Temperature Acidity  \
# 0          1  Harish Lingam   25    Male       101.00      no
# 1          2         Gopika   18  Female        98.00      no
# 2          3        Shaheen   20  Female       100.00     yes
# 3          4        Sweatha   23  Female        99.69     yes
# 4          5          Noura   13  Female       100.90     yes
# 5          6      Hariharan   19    Male        99.70      no
# 6          7        Kishore   32    Male       105.40     yes
# 7          8          Selvi   33  Female       100.10      no
# 8          9   Jebisha Lily   23  Female        98.20      no
# 9         10         Swathi   12  Female        96.30      no
# 10        11        Sathish   14    Male        97.20      no
# 11        12          Adhi    14  Female        99.30     yes
# 12        13      Sakthivel   24    Male       100.20     yes
# 13        14           Asha   53  Female       101.30      no
# ...

# %%
#first 5 rows
df.head(10)
# Out:
#    Token No           Name  Age  Gender  Temperature Acidity  \
# 0         1  Harish Lingam   25    Male       101.00      no
# 1         2         Gopika   18  Female        98.00      no
# 2         3        Shaheen   20  Female       100.00     yes
# 3         4        Sweatha   23  Female        99.69     yes
# 4         5          Noura   13  Female       100.90     yes
# 5         6      Hariharan   19    Male        99.70      no
# 6         7        Kishore   32    Male       105.40     yes
# 7         8          Selvi   33  Female       100.10      no
# 8         9   Jebisha Lily   23  Female        98.20      no
# 9        10         Swathi   12  Female        96.30      no
#
#   vomiting sensation cold Headache diarrhoea Duration Fever         Type
# 0                yes  yes      yes        no   1 week   yes       dengue
# 1                 no  yes       no       yes   2 days    no          NaN
# 2                 no  yes       no        no    1 day    no          NaN
# ...

# %%
#last 5 rows
df.tail()
# Out:
#     Token No        Name  Age  Gender  Temperature Acidity vomiting sensation  \
# 27        28  Manikandan   18    Male        100.0     yes                NaN
# 28        29        Esai   23  Female         98.7      no                yes
# 29        30     Preetha   21     NaN         99.1      no                yes
# 30        31       Mohan   32    Male        101.3     yes                 no
# 31        32        Vasu   23    Male        100.2      no                 no
#
#    cold Headache diarrhoea Duration Fever          Type
# 27   no      yes        no    1 day    no           NaN
# 28   no       no        no    1 day   yes           NaN
# 29   no      NaN       yes      NaN    no  normal fever
# 30   no      yes        no    1 day   yes      jaundice
# 31   no      yes        no   3 days    no  normal fever

# %%
#rows and columns
df.shape
# Out:
# (32, 13)

# %%
#column names
df.columns
# Out:
# Index(['Token No', 'Name', 'Age', 'Gender', 'Temperature', 'Acidity',
#        'vomiting sensation', 'cold', 'Headache', 'diarrhoea', 'Duration',
#        'Fever', 'Type'],
#       dtype='object')

# %%
#data type info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Token No            32 non-null     int64
#  1   Name                32 non-null     object
#  2   Age                 32 non-null     int64
#  3   Gender              29 non-null     object
#  4   Temperature         32 non-null     float64
#  5   Acidity             32 non-null     object
#  6   vomiting sensation  30 non-null     object
#  7   cold                32 non-null     object
#  8   Headache            31 non-null     object
#  9   diarrhoea           31 non-null     object
#  10  Duration            30 non-null     object
#  11  Fever               31 non-null     object
#  12  Type                18 non-null     object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 3.4+ KB

# %%
#summary statistics
df.describe()
# Out:
#         Token No        Age  Temperature
# count  32.000000  32.000000    32.000000
# mean   16.500000  23.625000    99.961875
# std     9.380832   8.764849     1.845183
# min     1.000000  12.000000    96.300000
# 25%     8.750000  18.000000    99.100000
# 50%    16.500000  23.000000   100.000000
# 75%    24.250000  26.750000   100.375000
# max    32.000000  53.000000   105.400000

# %%
df['Name']
# Out:
# 0     Harish Lingam
# 1            Gopika
# 2           Shaheen
# 3           Sweatha
# 4             Noura
# 5         Hariharan
# 6           Kishore
# 7             Selvi
# 8      Jebisha Lily
# 9            Swathi
# 10          Sathish
# 11            Adhi
# 12        Sakthivel
# 13             Asha
# 14       Manikandan
# 15             Esai
# 16          Preetha
# 17            Mohan
# 18             Vasu
# 19             Maha
# 20           Gopika
# 21          Shaheen
# 22          Sweatha
# 23            Noura
# 24        Hariharan
# 25          Kishore
# 26            Selvi
# 27       Manikandan
# 28             Esai
# 29          Preetha
# 30            Mohan
# 31             Vasu
# Name: Name, dtype: object

# %%
df[['Name','Age']]
# Out:
#              Name  Age
# 0   Harish Lingam   25
# 1          Gopika   18
# 2         Shaheen   20
# 3         Sweatha   23
# 4           Noura   13
# 5       Hariharan   19
# 6         Kishore   32
# 7           Selvi   33
# 8    Jebisha Lily   23
# 9          Swathi   12
# 10        Sathish   14
# 11          Adhi    14
# 12      Sakthivel   24
# 13           Asha   53
# 14     Manikandan   18
# 15           Esai   23
# 16        Preetha   21
# 17          Mohan   32
# 18           Vasu   23
# 19           Maha   41
# 20         Gopika   18
# 21        Shaheen   20
# 22        Sweatha   23
# 23          Noura   13
# 24      Hariharan   19
# 25        Kishore   32
# 26          Selvi   33
# 27     Manikandan   18
# 28           Esai   23
# 29        Preetha   21
# 30          Mohan   32
# 31           Vasu   23

# %%
#random data
df.sample(4)
# Out:
#     Token No           Name  Age Gender  Temperature Acidity  \
# 31        32           Vasu   23   Male        100.2      no
# 18        19           Vasu   23   Male        100.2      no
# 0          1  Harish Lingam   25   Male        101.0      no
# 25        26        Kishore   32   Male        105.4     yes
#
#    vomiting sensation cold Headache diarrhoea Duration Fever          Type
# 31                 no   no      yes        no   3 days    no  normal fever
# 18                 no   no      yes        no   3 days    no  normal fever
# 0                 yes  yes      yes        no   1 week   yes        dengue
# 25                yes  yes      yes       yes  2 weeks   yes        corona

# %%
#32 rows and 13 colns so 32x13
df.size
# Out:
# 416

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
df.dtypes
# Out:
# Token No                int64
# Name                   object
# Age                     int64
# Gender                 object
# Temperature           float64
# Acidity                object
# vomiting sensation     object
# cold                   object
# Headache               object
# diarrhoea              object
# Duration               object
# Fever                  object
# Type                   object
# dtype: object

# %%
df.iloc[0]
# Out:
# Token No                          1
# Name                  Harish Lingam
# Age                              25
# Gender                         Male
# Temperature                   101.0
# Acidity                          no
# vomiting sensation              yes
# cold                            yes
# Headache                        yes
# diarrhoea                        no
# Duration                     1 week
# Fever                           yes
# Type                         dengue
# Name: 0, dtype: object

# %%
#till last index 
df.loc[0:3]
# Out:
#    Token No           Name  Age  Gender  Temperature Acidity  \
# 0         1  Harish Lingam   25    Male       101.00      no
# 1         2         Gopika   18  Female        98.00      no
# 2         3        Shaheen   20  Female       100.00     yes
# 3         4        Sweatha   23  Female        99.69     yes
#
#   vomiting sensation cold Headache diarrhoea Duration Fever     Type
# 0                yes  yes      yes        no   1 week   yes   dengue
# 1                 no  yes       no       yes   2 days    no      NaN
# 2                 no  yes       no        no    1 day    no      NaN
# 3                yes  yes      yes       yes   5 days   yes  typhoid

# %%
#last index n-1

df.iloc[0:3]
# Out:
#    Token No           Name  Age  Gender  Temperature Acidity  \
# 0         1  Harish Lingam   25    Male        101.0      no
# 1         2         Gopika   18  Female         98.0      no
# 2         3        Shaheen   20  Female        100.0     yes
#
#   vomiting sensation cold Headache diarrhoea Duration Fever    Type
# 0                yes  yes      yes        no   1 week   yes  dengue
# 1                 no  yes       no       yes   2 days    no     NaN
# 2                 no  yes       no        no    1 day    no     NaN

# %%
df.loc[0]
# Out:
# Token No                          1
# Name                  Harish Lingam
# Age                              25
# Gender                         Male
# Temperature                   101.0
# Acidity                          no
# vomiting sensation              yes
# cold                            yes
# Headache                        yes
# diarrhoea                        no
# Duration                     1 week
# Fever                           yes
# Type                         dengue
# Name: 0, dtype: object

# %%
#null=true,not null=false
df.isnull()
# Out:
#     Token No   Name    Age  Gender  Temperature  Acidity  vomiting sensation  \
# 0      False  False  False   False        False    False               False
# 1      False  False  False   False        False    False               False
# 2      False  False  False   False        False    False               False
# 3      False  False  False   False        False    False               False
# 4      False  False  False   False        False    False               False
# 5      False  False  False   False        False    False               False
# 6      False  False  False   False        False    False               False
# 7      False  False  False   False        False    False               False
# 8      False  False  False   False        False    False               False
# 9      False  False  False   False        False    False               False
# 10     False  False  False   False        False    False               False
# ...

# %%
df.isnull().sum()
# Out:
# Token No               0
# Name                   0
# Age                    0
# Gender                 3
# Temperature            0
# Acidity                0
# vomiting sensation     2
# cold                   0
# Headache               1
# diarrhoea              1
# Duration               2
# Fever                  1
# Type                  14
# dtype: int64

# %%
#null=false,not null=true
df.notnull()
# Out:
#     Token No  Name   Age  Gender  Temperature  Acidity  vomiting sensation  \
# 0       True  True  True    True         True     True                True
# 1       True  True  True    True         True     True                True
# 2       True  True  True    True         True     True                True
# 3       True  True  True    True         True     True                True
# 4       True  True  True    True         True     True                True
# 5       True  True  True    True         True     True                True
# 6       True  True  True    True         True     True                True
# 7       True  True  True    True         True     True                True
# 8       True  True  True    True         True     True                True
# 9       True  True  True    True         True     True                True
# 10      True  True  True    True         True     True                True
# ...

# %%
#fill null values with 0
df.fillna(0)
# Out:
#     Token No           Name  Age  Gender  Temperature Acidity  \
# 0          1  Harish Lingam   25    Male       101.00      no
# 1          2         Gopika   18  Female        98.00      no
# 2          3        Shaheen   20  Female       100.00     yes
# 3          4        Sweatha   23  Female        99.69     yes
# 4          5          Noura   13  Female       100.90     yes
# 5          6      Hariharan   19    Male        99.70      no
# 6          7        Kishore   32    Male       105.40     yes
# 7          8          Selvi   33  Female       100.10      no
# 8          9   Jebisha Lily   23  Female        98.20      no
# 9         10         Swathi   12  Female        96.30      no
# 10        11        Sathish   14    Male        97.20      no
# 11        12          Adhi    14  Female        99.30     yes
# 12        13      Sakthivel   24    Male       100.20     yes
# 13        14           Asha   53  Female       101.30      no
# ...

# %%
#if there is null value drop the row
df.dropna()
# Out:
#     Token No           Name  Age  Gender  Temperature Acidity  \
# 0          1  Harish Lingam   25    Male       101.00      no
# 3          4        Sweatha   23  Female        99.69     yes
# 4          5          Noura   13  Female       100.90     yes
# 6          7        Kishore   32    Male       105.40     yes
# 9         10         Swathi   12  Female        96.30      no
# 11        12          Adhi    14  Female        99.30     yes
# 12        13      Sakthivel   24    Male       100.20     yes
# 13        14           Asha   53  Female       101.30      no
# 16        17        Preetha   21  Female        99.10      no
# 17        18          Mohan   32    Male       101.30     yes
# 18        19           Vasu   23    Male       100.20      no
# 19        20           Maha   41  Female        99.10      no
# 23        24          Noura   13  Female       100.90     yes
# 25        26        Kishore   32    Male       105.40     yes
# ...
