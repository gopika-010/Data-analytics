# %%
import numpy as np

# %%
#arrray creation

# %%
#zero dimension array
a=np.array(5)
a
# Out:
# array(5)

# %%
#one dimensional array
b=np.array([1,2,3])
print(b)
# Out:
# [1 2 3]

# %%
b
# Out:
# array([1, 2, 3])

# %%
#two dimensional array
c=np.array([[1,2,3],[4,5,6]])
c
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
print(c)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#3 dimensional array
d=np.array([[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]]])
d
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]]])

# %%
e=np.array("Gopi")
e
# Out:
# array('Gopi', dtype='<U4')

# %%
print(e)
# Out:
# Gopi

# %%
f=np.array(['swea','noura'])
print(f)
# Out:
# ['swea' 'noura']

# %%
f
# Out:
# array(['swea', 'noura'], dtype='<U5')

# %%
g=np.array([['swea','noura'],['gopi','shaheen']])
print(g)
# Out:
# [['swea' 'noura']
#  ['gopi' 'shaheen']]

# %%
h=np.array([[['swea','noura'],['gopi','shaheen']],[['swea','noura'],['gopi','shaheen']]])
h
# Out:
# array([[['swea', 'noura'],
#         ['gopi', 'shaheen']],
#
#        [['swea', 'noura'],
#         ['gopi', 'shaheen']]], dtype='<U7')

# %%
print(h)
# Out:
# [[['swea' 'noura']
#   ['gopi' 'shaheen']]
#
#  [['swea' 'noura']
#   ['gopi' 'shaheen']]]

# %%
#array of zeros

i=np.zeros((2,3))
print(i)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
#array of ones

j=np.ones((2,3))
print(j)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
# even numbers

k=np.arange(0,10,3)
print(k)
# Out:
# [0 3 6 9]

# %%
#5 values between respective numbers

l=np.linspace(0,1,5)
print(l)
# Out:
# [0.   0.25 0.5  0.75 1.  ]

# %%
#shape(rows,columns)

m=np.array([[1,2,3],[4,5,6]])
print(m)
print(m.shape)
# Out:
# [[1 2 3]
#  [4 5 6]]
# (2, 3)

# %%
#no. of dimensions
print(m.ndim)
# Out:
# 2

# %%
#data type
print(m.dtype)
# Out:
# int64

# %%
#indexing
print(m[0,1])
# Out:
# 2

# %%
#slicing
print(b[1:3])
# Out:
# [2 3]

# %%
#add scalar
print(m+5)
# Out:
# [[ 6  7  8]
#  [ 9 10 11]]

# %%
#multiplying
print(m*2)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]

# %%
#element wise addition
print(b+m[0])
# Out:
# [2 4 6]

# %%
#matrix multiplication
print(np.dot(c,m.T)) #dimension 2x3 ; 3x2
# Out:
# [[14 32]
#  [32 77]]

# %%
print(c.shape)
print(m.shape)
# Out:
# (2, 3)
# (2, 3)

# %%
#sum of elements
print(np.sum(m))
# Out:
# 21

# %%
#average
print(np.mean(m))
# Out:
# 3.5

# %%
#max value
print(np.max(m))
# Out:
# 6

# %%
#square root
print(np.sqrt(m))
# Out:
# [[1.         1.41421356 1.73205081]
#  [2.         2.23606798 2.44948974]]

# %%
n=np.arange(6).reshape(2,3)
print(n)
# Out:
# [[0 1 2]
#  [3 4 5]]
