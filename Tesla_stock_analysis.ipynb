# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("TSLA.csv")

# %%
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     29-06-2010   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     30-06-2010   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     01-07-2010   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     02-07-2010   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     06-07-2010   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  28-01-2020  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  29-01-2020  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  30-01-2020  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  31-01-2020  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  03-02-2020  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 0     18766300
# 1     17187100
# 2      8218800
# 3      5139800
# 4      6866900
# ...        ...
# 2411  11788500
# 2412  17801500
# 2413  29005700
# 2414  15719300
# 2415  47065000
#
# [2416 rows x 7 columns]

# %%
data.set_index('Date')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 29-06-2010   19.000000   25.000000   17.540001   23.889999   23.889999
# 30-06-2010   25.790001   30.420000   23.299999   23.830000   23.830000
# 01-07-2010   25.000000   25.920000   20.270000   21.959999   21.959999
# 02-07-2010   23.000000   23.100000   18.709999   19.200001   19.200001
# 06-07-2010   20.000000   20.000000   15.830000   16.110001   16.110001
# ...                ...         ...         ...         ...         ...
# 28-01-2020  568.489990  576.809998  558.080017  566.900024  566.900024
# 29-01-2020  575.690002  589.799988  567.429993  580.989990  580.989990
# 30-01-2020  632.419983  650.880005  618.000000  640.809998  640.809998
# 31-01-2020  640.000000  653.000000  632.520020  650.570007  650.570007
# 03-02-2020  673.690002  786.140015  673.520020  780.000000  780.000000
#
#               Volume
# Date
# 29-06-2010  18766300
# 30-06-2010  17187100
# 01-07-2010   8218800
# 02-07-2010   5139800
# 06-07-2010   6866900
# ...              ...
# 28-01-2020  11788500
# 29-01-2020  17801500
# 30-01-2020  29005700
# 31-01-2020  15719300
# 03-02-2020  47065000
#
# [2416 rows x 6 columns]

# %%
plt.figure(figsize=(14,10))
data['Close'].plot()
plt.show()

# %%
df_close=data['Close']
plt.figure(figsize=(14,10))
df_close.plot(style='k.')
plt.title('scatter plot of closing price')
plt.show()

# %%
data['price_diff']=data['Close'].shift(-1)
data['price_diff']
# Out:
# 0        23.830000
# 1        21.959999
# 2        19.200001
# 3        16.110001
# 4        15.800000
#            ...
# 2411    580.989990
# 2412    640.809998
# 2413    650.570007
# 2414    780.000000
# 2415           NaN
# Name: price_diff, Length: 2416, dtype: float64

# %%
data['daily_rn']=data['price_diff']/data['Close']
data['daily_rn']
# Out:
# 0       0.997489
# 1       0.921527
# 2       0.874317
# 3       0.839063
# 4       0.980757
#           ...
# 2411    1.024854
# 2412    1.102962
# 2413    1.015231
# 2414    1.198949
# 2415         NaN
# Name: daily_rn, Length: 2416, dtype: float64

# %%
data['ra50']=data['Close'].rolling(50).mean()
plt.figure(figsize=(14,10))
data['ra50'].plot()
data['Close'].plot()
plt.legend()
plt.show()

# %%
data['ra10']=data['Close'].rolling(10).mean()
plt.figure(figsize=(14,10))
data['ra10'].plot()
data['Close'].plot()
plt.legend()
plt.show()
# Out:
# C:\Users\GOPIKA\AppData\Local\Temp\ipykernel_11652\2365900008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['ra10']=data['Close'].rolling(10).mean()

# %%
data=data.dropna()
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 49    08-09-2010   20.660000   20.950001   20.600000   20.900000   20.900000
# 50    09-09-2010   21.000000   21.049999   20.690001   20.709999   20.709999
# 51    10-09-2010   20.750000   20.930000   19.760000   20.170000   20.170000
# 52    13-09-2010   20.889999   20.900000   20.500000   20.719999   20.719999
# 53    14-09-2010   20.540001   21.600000   20.530001   21.120001   21.120001
# ...          ...         ...         ...         ...         ...         ...
# 2410  27-01-2020  541.989990  564.440002  539.280029  558.020020  558.020020
# 2411  28-01-2020  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  29-01-2020  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  30-01-2020  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  31-01-2020  640.000000  653.000000  632.520020  650.570007  650.570007
#
#         Volume  price_diff  daily_rn        ra50        ra10
# 49      288400   20.709999  0.990909   19.833600   20.270000
# 50      376200   20.170000  0.973926   19.770000   20.351000
# 51      386600   20.719999  1.027268   19.696800   20.393000
# 52      360800   21.120001  1.019305   19.672000   20.495000
# 53      654700   21.980000  1.040720   19.710400   20.620000
# ...        ...         ...       ...         ...         ...
# 2410  13608100  566.900024  1.015913  414.357601  541.707001
# 2411  11788500  580.989990  1.024854  418.773402  545.911005
# 2412  17801500  640.809998  1.102962  423.406202  550.218005
# 2413  29005700  650.570007  1.015231  429.179001  562.449005
# 2414  15719300  780.000000  1.198949  435.190602  576.157007
#
# [2366 rows x 11 columns]

# %%
data['Shares']=[1 if data.loc[ei,'ra10']>data.loc[ei,'ra50'] else 0 for ei in data .index]
# Out:
# C:\Users\GOPIKA\AppData\Local\Temp\ipykernel_11652\3331496765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Shares']=[1 if data.loc[ei,'ra10']>data.loc[ei,'ra50'] else 0 for ei in data .index]

# %%
data['Close1']=data['Close'].shift(-1)
data['Profit']=[data.loc[ei,'Close1']-data.loc[ei,'Close'] if data.loc[ei,'Shares']==1 else 0 for ei in data.index]
data['Profit'].plot()
plt.axhline(y=0,color='red')
# Out:
# C:\Users\GOPIKA\AppData\Local\Temp\ipykernel_11652\185539109.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Close1']=data['Close'].shift(-1)
# C:\Users\GOPIKA\AppData\Local\Temp\ipykernel_11652\185539109.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Profit']=[data.loc[ei,'Close1']-data.loc[ei,'Close'] if data.loc[ei,'Shares']==1 else 0 for ei in data.index]

# %%
data['log_return']=np.log(data['Close'].shift(-1))-np.log(data['Close'])
data['log_return']
# Out:
# C:\Users\GOPIKA\AppData\Local\Temp\ipykernel_11652\1058313656.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['log_return']=np.log(data['Close'].shift(-1))-np.log(data['Close'])
# 49     -0.009133
# 50     -0.026420
# 51      0.026903
# 52      0.019121
# 53      0.039912
#           ...
# 2410    0.015788
# 2411    0.024551
# 2412    0.097999
# 2413    0.015116
# 2414         NaN
# Name: log_return, Length: 2366, dtype: float64

# %%
from scipy.stats import norm
mu=data['log_return'].mean()
sigma=data['log_return'].std(ddof=1)

density=pd.DataFrame()
density['x']=np.arange(data['log_return'].min()-0.01,data['log_return'].max()+0.01,0.001)
density['pdf']=norm.pdf(density['x'],mu,sigma)

data['log_return'].hist(bins=50,figsize=(15,8))
plt.plot(density['x'],density['pdf'],color='red')
plt.show()

# %%
prob_return1=norm.cdf(-0.10,mu,sigma)
print('The probability of dropping over 10% in one day',prob_return1)
# Out:
# The probability of dropping over 10% in one day 0.0007272322154809123

# %%
mu220=365*mu
sigma220=(365**0.5)*sigma
drop20=None
print('The probability of dropping over 25% over a year:',drop20)
# Out:
# The probability of dropping over 25% over a year: None

# %%
from pandas.plotting import scatter_matrix
sm=scatter_matrix(data,figsize=(10,10))
